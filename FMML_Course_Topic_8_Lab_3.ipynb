# %% [markdown]
# <a href="https://colab.research.google.com/github/SriDivya3009/Fmml/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-05-15 14:12:23--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  59.5MB/s    in 1.2s
#
# 2024-05-15 14:12:29 (59.5 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 162    1705.10119v3  Recent progress in variational inference has p...  stat
# 11070   1312.7651v2  What is a systematic way to efficiently apply ...  stat
# 22325  1602.01182v2  Regularized discriminant analysis (RDA), propo...  stat
# 13938  1609.01982v1  A theoretical framework is developed to descri...    cs
# 10553   1303.0283v2  The paper presents new machine learning method...    cs
# ...             ...                                                ...   ...
# 9916   1612.07139v3  Deep-learning has dramatically changed the wor...    cs
# 11383  1511.08681v1  We present differentially private algorithms f...  stat
# 13124  1610.06656v2  In this paper we present a new algorithm for c...  stat
# 40319  cs/0003072v1  Ports, warehouses and courier services have to...    cs
# 5523    1205.4656v2  We demonstrate an equivalence between reproduc...    cs
#
#                                                    title  year  \
# 162                Kernel Implicit Variational Inference  2017
# 11070  Petuum: A New Platform for Distributed Machine...  2013
# 22325  High-Dimensional Regularized Discriminant Anal...  2016
# 13938  Uniform Transformation of Non-Separable Probab...  2016
# 10553  Inverse Signal Classification for Financial In...  2013
# ...                                                  ...   ...
# 9916   Deep-learning in Mobile Robotics - from Percep...  2016
# 11383  Algorithms for Differentially Private Multi-Ar...  2015
# 13124                 Single Pass PCA of Matrix Products  2016
# 40319  MOO: A Methodology for Online Optimization thr...  2000
# 5523   Conditional mean embeddings as regressors - su...  2012
#
#                                                 keywords
# 162    [variational, inference, attention, flexibilit...
# 11070  [systematic, efficiently, industrial, terabyte...
# 22325  [regularized, discriminant, classifier, interp...
# 13938  [theoretical, framework, developed, transforma...
# 10553  [composition, classifies, regardless, supervis...
# ...                                                  ...
# 9916   [dramatically, overnight, development, percept...
# 11383  [differentially, algorithms, stochastic, appli...
# 13124  [algorithm, computing, approximation, straight...
# 40319  [warehouses, minimized, operators, historical,...
# 5523   [demonstrate, equivalence, reproducing, embedd...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 162      [variational, inference, attention, flexibilit...
# 11070    [systematic, efficiently, industrial, terabyte...
# 22325    [regularized, discriminant, classifier, interp...
# 13938    [theoretical, framework, developed, transforma...
# 10553    [composition, classifies, regardless, supervis...
#                                ...
# 1011     [generalizing, operations, architectures, expl...
# 15351    [fundamental, semantics, processing, analysing...
# 22339    [replacement, technique, validation, bootstrap...
# 22113    [introduce, factorization, formulation, factor...
# 3781     [inference, classification, increasingly, impo...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8913 words.
# Out of those 4598 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4fb4bfb9-500a-4674-a222-1b760315cd1b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4fb4bfb9-500a-4674-a222-1b760315cd1b")) {                    Plotly.newPlot(                        "4fb4bfb9-500a-4674-a222-1b760315cd1b",                        [{"x":["densities","direction","distributions","challenges","addresses","tractable","inference","infeasibility","dimensional","variational","promising","successfully","posteriors","attention","estimation","flexibility","posterior","classification","regression","computational","variables","mapreduce","implementations","difficult","applicable","operations","systematically","considerably","parallelization","efficiently","synchronization","representations","iterative","directions","optimization","scheduling","framework","processing","solutions","terabytes","popularized","systematic","structure","opportunities","approaches","algorithms","execution","observing","synchronous","convergent","industrial","algorithmic","integrative","distributed","demonstrate","specialized","fundamentally","different","strategies","universal","drastically","approximately","increases","interpretability","estimator","regardless","resulting","artificial","formulation","efficient","classifiers","comparisons","impractical","classifier","implementation","covariance","interpretable","computationally","observation","contributes","equivalent","regularized","dimension","discriminant","cumulative","distribution","uniformly","probability","distributes","numerical","functions","theoretical","transformation","developed","dimensions","potential","generalize","separable","instruments","financial","composition","enhancement","classifies","supervised","describes","collection","filtering","optimized","indicates","superiority","correlation","especially","experimental","combination","competing","transforms","implement","constructed","efficiency","candidate","canonical","frequency","constrained","reference","recognition","comparison","interfaces","completely","demonstrates","perturbed","resilience","instances","distances","parameters","clustering","perturbations","interesting","objectives","correspondence","introduced","stability","sometimes","consequences","assumptions","resilient","multiplicative","examination","motivated","difficulty","expression","understanding","meaningful","importance","representation","transparent","landscape","incomplete","interactions","interaction","effectiveness","characterization","statistical","simulated","complexity","representing","properties","represented","partially","algorithm","determinant","correlated","parametric","generalized","interpretations","important","reactions","coefficients","landscapes","providing","applications","treatments","particles","holographic","techniques","reconstruction","macroscopic","prototype","compressive","compressed","resolution","tomographic","acquisition","discussion","recording","modulation","discussed","separately","implemented","presented","establish"],"y":[4,58,137,111,54,28,192,1,194,40,104,79,6,188,185,36,42,501,122,301,112,7,34,156,51,70,21,31,6,152,7,244,75,30,323,26,579,285,137,1,4,38,348,12,447,593,38,16,7,7,15,46,4,92,554,25,4,758,100,46,17,33,54,22,23,18,142,125,89,416,103,30,15,149,132,24,26,87,61,12,41,32,67,14,13,223,18,173,3,82,216,152,57,205,38,127,52,12,4,11,32,37,11,220,83,68,48,61,23,37,61,132,366,109,23,18,70,63,143,60,12,55,60,48,384,142,13,26,47,8,4,105,29,250,140,26,58,26,28,135,42,26,9,71,4,13,9,57,41,54,143,59,78,394,9,15,35,67,83,228,27,162,58,234,77,220,82,53,815,2,25,49,69,18,349,6,46,5,83,422,5,5,2,382,90,2,21,14,24,117,3,43,32,12,7,43,32,93,176,56],"type":"bar"},{"x":["densities","direction","distributions","challenges","address ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4598,), (4598, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8083333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Semi</span> <span style=''>bounded</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>Rationality</span> <span style=''>A</span> <span style=''>model</span> <span style=''>for</span> <span style=''>decision</span> <span style=''>making</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>the</span> <span style=''>theory</span> <span style=''>of</span> <span style=''>semi</span> <span style=''>bounded</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>rationality</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>as</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extension</span> <span style=''>of</span> <span style=''>the</span> <span style=''>theory</span> <span style=''>of</span> <span style=''>bounded</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>rationality</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>it</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>that</span> <span style=''>a</span> <span style=''>decision</span> <span style=''>making</span> <span style=''>process</span> <span style=''>involves</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>components</span> <span style=''>and</span> <span style=''>these</span> <span style=''>are</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correlation</span> <span style=''>machine</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimates</span> <span style=''>missing</span> <span style=''>values</span> <span style=''>and</span> <span style=''>the</span> <span style=''>causal</span> <span style=''>machine</span> <span style=''>which</span> <span style=''>relates</span> <span style=''>the</span> <span style=''>cause</span> <span style=''>to</span> <span style=''>the</span> <span style=''>effect</span> <span style=''>Rational</span> <span style=''>decision</span> <span style=''>making</span> <span style=''>involves</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.30769230769230765);'>information</span> <span style=''>which</span> <span style=''>is</span> <span style=''>almost</span> <span style=''>always</span> <span style='background-color:rgba(0, 255, 0, 0.6363636363636365);'>imperfect</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>incomplete</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.9032258064516129);'>intelligent</span> <span style=''>machine</span> <span style=''>which</span> <span style=''>if</span> <span style=''>it</span> <span style=''>is</span> <span style=''>a</span> <span style=''>human</span> <span style=''>being</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.5294117647058824);'>inconsistent</span> <span style=''>to</span> <span style=''>make</span> <span style='background-color:rgba(0, 255, 0, 0.5428571428571429);'>decisions</span> <span style=''>In</span> <span style=''>the</span> <span style=''>theory</span> <span style=''>of</span> <span style=''>bounded</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>rationality</span> <span style=''>this</span> <span style=''>decision</span> <span style=''>is</span> <span style=''>made</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>irrespective</span> <span style=''>of</span> <span style=''>the</span> <span style=''>fact</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.30769230769230765);'>information</span> <span style=''>to</span> <span style=''>be</span> <span style=''>used</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Convergent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Expectation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Propagation</span> <span style=''>in</span> <span style=''>Linear</span> <span style=''>Models</span> <span style=''>with</span> <span style=''>Spike</span> <span style=''>and</span> <span style=''>slab</span> <span style=''>Priors</span> <br/><br/><span style=''>Exact</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>in</span> <span style=''>the</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>model</span> <span style=''>with</span> <span style=''>spike</span> <span style=''>and</span> <span style=''>slab</span> <span style=''>priors</span> <span style=''>is</span> <span style=''>often</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intractable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Expectation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>propagation</span> <span style=''>(EP)</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>However</span> <span style=''>the</span> <span style=''>regular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequential</span> <span style=''>form</span> <span style=''>of</span> <span style=''>EP</span> <span style=''>(R</span> <span style=''>EP)</span> <span style=''>may</span> <span style=''>fail</span> <span style=''>to</span> <span style=''>converge</span> <span style=''>in</span> <span style=''>this</span> <span style=''>model</span> <span style=''>when</span> <span style=''>the</span> <span style=''>size</span> <span style=''>of</span> <span style=''>the</span> <span style=''>training</span> <span style=''>set</span> <span style=''>is</span> <span style=''>very</span> <span style=''>small</span> <span style=''>As</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternative</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>provably</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergent</span> <span style=''>EP</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>(PC</span> <span style=''>EP)</span> <span style=''>PC</span> <span style=''>EP</span> <span style=''>is</span> <span style=''>proved</span> <span style=''>to</span> <span style=''>minimize</span> <span style=''>an</span> <span style=''>energy</span> <span style=''>function</span> <span style=''>which</span> <span style=''>under</span> <span style=''>some</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraints</span> <span style=''>is</span> <span style=''>bounded</span> <span style=''>from</span> <span style=''>below</span> <span style=''>and</span> <span style=''>whose</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stationary</span> <span style=''>points</span> <span style=''>coincide</span> <span style=''>with</span> <span style=''>the</span> <span style=''>solution</span> <span style=''>of</span> <span style=''>R</span> <span style=''>EP</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Experiments</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>synthetic</span> <span style=''>data</span> <span style=''>indicate</span> <span style=''>that</span> <span style=''>when</span> <span style=''>R</span> <span style=''>EP</span> <span style=''>does</span> <span style=''>not</span> <span style=''>converge</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style='background-color:rgba(255,  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Anomaly</span> <span style='background-color:rgba(0, 255, 0, 0.5299539170506912);'>Detection</span> <span style=''>with</span> <span style=''>Score</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>based</span> <span style=''>on</span> <span style=''>Nearest</span> <span style=''>Neighbor</span> <span style=''>Graphs</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.3422818791946309);'>parametric</span> <span style=''>adaptive</span> <span style=''>anomaly</span> <span style='background-color:rgba(0, 255, 0, 0.5299539170506912);'>detection</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3240418118466899);'>dimensional</span> <span style=''>data</span> <span style=''>based</span> <span style=''>on</span> <span style=''>score</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>derived</span> <span style=''>from</span> <span style=''>nearest</span> <span style=''>neighbor</span> <span style=''>graphs</span> <span style=''>on</span> <span style=''>n</span> <span style=''>point</span> <span style=''>nominal</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Anomalies</span> <span style=''>are</span> <span style=''>declared</span> <span style=''>whenever</span> <span style=''>the</span> <span style=''>score</span> <span style=''>of</span> <span style=''>a</span> <span style=''>test</span> <span style=''>sample</span> <span style=''>falls</span> <span style=''>below</span> <span style=''>alpha</span> <span style=''>which</span> <span style=''>is</span> <span style=''>supposed</span> <span style=''>to</span> <span style=''>be</span> <span style=''>the</span> <span style=''>desired</span> <span style=''>false</span> <span style=''>alarm</span> <span style=''>level</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resulting</span> <span style=''>anomaly</span> <span style=''>detector</span> <span style=''>is</span> <span style=''>shown</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.5185185185185184);'>asymptotically</span> <span style=''>optimal</span> <span style=''>in</span> <span style=''>that</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>uniformly</span> <span style=''>most</span> <span style=''>powerful</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>specified</span> <span style=''>false</span> <span style=''>alarm</span> <span style=''>level</span> <span style=''>alpha</span> <span style=''>for</span> <span style=''>the</span> <span style=''>case</span> <span style=''>when</span> <span style=''>the</span> <span style=''>anomaly</span> <span style=''>density</span> <span style=''>is</span> <span style=''>a</span> <span style=''>mixture</span> <span style=''>of</span> <span style=''>the</span> <span style=''>nominal</span> <span style=''>and</span> <span style=''>a</span> <span style=''>known</span> <span style=''>density</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computationally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>being</span> <span style=''>linear</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.32323232323232315);'>dimension</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>quadratic</span> <span style=''>in</span> <span style=''>data</span> <span style ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Contrastive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Principal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Component</span> <span style=''>Analysis</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>called</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contrastive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>analysis</span> <span style=''>(cPCA)</span> <span style=''>that</span> <span style=''>is</span> <span style=''>designed</span> <span style=''>to</span> <span style=''>discover</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>that</span> <span style=''>is</span> <span style=''>unique</span> <span style=''>to</span> <span style=''>a</span> <span style=''>dataset</span> <span style=''>or</span> <span style=''>enriched</span> <span style=''>in</span> <span style=''>one</span> <span style=''>dataset</span> <span style=''>relative</span> <span style=''>to</span> <span style=''>other</span> <span style=''>data</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>of</span> <span style=''>standard</span> <span style=''>PCA</span> <span style=''>for</span> <span style=''>the</span> <span style=''>setting</span> <span style=''>where</span> <span style=''>multiple</span> <span style=''>datasets</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>eg</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatment</span> <span style=''>and</span> <span style=''>a</span> <span style=''>control</span> <span style=''>group</span> <span style=''>or</span> <span style=''>a</span> <span style=''>mixed</span> <span style=''>versus</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>homogeneous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>population</span> <span style=''>and</span> <span style=''>the</span> <span style=''>goal</span> <span style=''>is</span> <span style=''>to</span> <span style=''>explore</span> <span style=''>patterns</span> <span style=''>that</span> <span style=''>are</span> <span style=''>specific</span> <span style=''>to</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>datasets</span> <span style=''>We</span> <span style=''>conduct</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>variety</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>in</span> <span style=''>which</span> <span style=''>cPCA</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identifies</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>dataset</span> <span style=''>specific</span> <span style=''>patterns</span> <span style=''>that</span> <span style=''>are</span> <span style=''>missed</span> <span style=''>by</span> <span style=''>PCA</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrating</span> <span style=''>that</span> <span style=''>it</span> <span style=''>is</span> <span style=''>useful</span> <span style=''>for</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>subgroup</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discovery< ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10153188457427859)
# 	segmentation (0.06590666191663698)
# 	architecture (0.09120057000356252)
# 	knowledge (0.13110081938012114)
# 	representation (0.14036337727110795)
# 	information (0.2543640897755611)
# 	detection (0.11827573922337015)
# 	different (0.2700391877449234)
# 	recognition (0.13680085500534378)
# 	convolutional (0.1350195938724617)
#
# Some Statistics words are:
# 	stochastic (0.1359759157049674)
# 	theoretical (0.1545408931259408)
# 	statistical (0.1620672353236327)
# 	algorithm (0.39989964877069745)
# 	estimation (0.17661816357250376)
# 	variables (0.15253386853988962)
# 	distribution (0.19367787255393878)
# 	dimensional (0.19066733567486202)
# 	inference (0.2002007024586051)
# 	regression (0.1821374811841445)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5671ad49-3f44-4892-b751-1bc2a6b2e322" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5671ad49-3f44-4892-b751-1bc2a6b2e322")) {                    Plotly.newPlot(                        "5671ad49-3f44-4892-b751-1bc2a6b2e322",                        [{"x":["densities","direction","distributions","challenges","addresses","tractable","inference","infeasibility","dimensional","variational","promising","successfully","posteriors","attention","estimation","flexibility","posterior","classification","regression","computational","variables","mapreduce","implementations","difficult","applicable","operations","systematically","considerably","parallelization","efficiently","synchronization","representations","iterative","directions","optimization","scheduling","framework","processing","solutions","terabytes","popularized","systematic","structure","opportunities","approaches","algorithms","execution","observing","synchronous","convergent","industrial","algorithmic","integrative","distributed","demonstrate","specialized","fundamentally","different","strategies","universal","drastically","approximately","increases","interpretability","estimator","regardless","resulting","artificial","formulation","efficient","classifiers","comparisons","impractical","classifier","implementation","covariance","interpretable","computationally","observation","contributes","equivalent","regularized","dimension","discriminant","cumulative","distribution","uniformly","probability","distributes","numerical","functions","theoretical","transformation","developed","dimensions","potential","generalize","separable","instruments","financial","composition","enhancement","classifies","supervised","describes","collection","filtering","optimized","indicates","superiority","correlation","especially","experimental","combination","competing","transforms","implement","constructed","efficiency","candidate","canonical","frequency","constrained","reference","recognition","comparison","interfaces","completely","demonstrates","perturbed","resilience","instances","distances","parameters","clustering","perturbations","interesting","objectives","correspondence","introduced","stability","sometimes","consequences","assumptions","resilient","multiplicative","examination","motivated","difficulty","expression","understanding","meaningful","importance","representation","transparent","landscape","incomplete","interactions","interaction","effectiveness","characterization","statistical","simulated","complexity","representing","properties","represented","partially","algorithm","determinant","correlated","parametric","generalized","interpretations","important","reactions","coefficients","landscapes","providing","applications","treatments","particles","holographic","techniques","reconstruction","macroscopic","prototype","compressive","compressed","resolution","tomographic","acquisition","discussion","recording","modulation","discussed","separately","implemented","presented","establish","minimization","logarithmic","completion","arbitrary","initialization","simulation","alternating","significantly","reconstructing","polynomial","underlying","computing","necessary","relationship","concentrate","fundamental","condition","sufficient","neighborhoods","significant","incorporating","improvement","empirically","mechanism","connection","utilizing","convergence","scientific","multiscale","machinery","performance","theoretically","discovery","population","statistic","correlations","multivariate","understand","univariate","nonlinear","imperative","formalize","simulations","statistics","asymptotic","illustrated","developing","characteristic","advantages","achieving","discoveries","desirable","comprehens ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	pretreatment
# 	lindenstrauss
# 	encrypted
# 	homomorphic
# 	conjugacy
# 	unsatisfying
# 	correspondingly
# 	penalizes
# 	factorisation
# 	regularised
# 	preconditioned
# 	normalizing
# 	lojasiewicz
# 	penalization
# 	extrapolation
# 	detrimental
# 	hypernetworks
# 	hypernetwork
# 	mislabeled
# 	ultrametric
# Some words which never appear in Statistics papers:
# 	resilience
# 	holographic
# 	tomographic
# 	photographs
# 	presently
# 	aesthetic
# 	substrate
# 	triangulation
# 	scattered
# 	adaptions
# 	centuries
# 	francisco
# 	undertaken
# 	manipulation
# 	instructions
# 	retrieves
# 	concurrently
# 	manufacturer
# 	adjectives
# 	bifurcation

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.061099546957267e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7683333333333333
